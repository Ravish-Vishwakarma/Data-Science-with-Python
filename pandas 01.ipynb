# %%
import pandas as pd
import numpy as np

# %%
# Creating an array
data = np.array([[1,4],[2,5],[3,6]])
data
# Out:
# array([[1, 4],
#        [2, 5],
#        [3, 6]])

# %%
# Creating a dataframe

# dataframe  = pd.DataFrame(data)
df = pd.DataFrame(data, index =['row1','row2','row3'],columns = ['col1','col2'])

# %%
# showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
# lists used for this example
states = ["Madhya Pradesh","Uttar Pradesh", "Arunachal Pradesh", "Maharastra"]
population = [100324,321512,5132,54232]

# %%
# sortings lists within a dictionary
dict_states = {'States': states, 'Population':population}

# %%
# Creating the dataframe from dic
df_data = pd.DataFrame(dict_states)

# %%
# Showing data
df_data
# Out:
#               States  Population
# 0     Madhya Pradesh      100324
# 1      Uttar Pradesh      321512
# 2  Arunachal Pradesh        5132
# 3         Maharastra       54232

# %%
# reading a csv file
df_exams = pd.read_csv('data/StudentsPerformance.csv')

# %%
df_exams.head() # top 5 rows
df_exams.tail() # bottom 5 rows
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams_female = df_exams[df_exams['gender'] == "female"]
df_exams_female
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df_male_toppers = df_exams[(df_exams["gender"]=="male") & (df_exams["math score"] >= 90)]
df_male_toppers
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 34    male        group E                some college      standard
# 104   male        group C                some college      standard
# 121   male        group B          associate's degree      standard
# 149   male        group E          associate's degree  free/reduced
# 171   male        group E            some high school      standard
# 233   male        group E            some high school      standard
# 286   male        group E          associate's degree      standard
# 299   male        group D          associate's degree  free/reduced
# 306   male        group E                some college      standard
# 333   male        group B          associate's degree      standard
# 469   male        group C                some college      standard
# 539   male        group A          associate's degree      standard
# 562   male        group C           bachelor's degree      standard
# ...

# %%
# showing n numbers of rows
df_exams.head(10)
df_exams.tail(10)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 990               completed          86             81             75
# ...

# %%
# Dimensions(shape) of the data frame
df_exams.shape
# Out:
# (1000, 8)

# %%
# display n rows
# pd.set_option('display.max_rows', 1000) # this will change the setting to show the entered no of rows (e.g 1000) in preview

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
len(df_exams) # no of rows
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams["gender"]
df_exams.gender
# both are same
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams.gender)
# Out:
# pandas.core.series.Series

# %%
df_exams[["gender","math score"]]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams[(df_exams['gender'] == 'female') & (df_exams['math score'] == 89)]
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 970  female        group D           bachelor's degree  standard
#
#     test preparation course  math score  reading score  writing score
# 970                    none          89            100            100

# %%
df_exams[['gender','lunch','math score']]
# Out:
#      gender         lunch  math score
# 0    female      standard          72
# 1    female      standard          69
# 2    female      standard          90
# 3      male  free/reduced          47
# 4      male      standard          76
# ..      ...           ...         ...
# 995  female      standard          88
# 996    male  free/reduced          62
# 997  female  free/reduced          59
# 998  female      standard          68
# 999  female  free/reduced          77
#
# [1000 rows x 3 columns]

# %%
# adding column to dataframe
df_exams['english score'] = 70

df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df_exams['english score'] =  np.where(df_exams['math score'] == 72,10,70)
df_exams[df_exams['english score'] == 10]
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# english_score = np.arange(0,1000)
english_score = np.random.randint(1,100, size=1000)
len(english_score)
df_exams['english score'] = english_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# Floating point numbers
np.random.uniform(1,100, size=100)
# Out:
# array([76.97577752, 90.67760481, 73.03541701, 35.26285957, 56.80575936,
#        80.74278594,  9.56754077, 14.24525362, 19.86076547, 62.37554915,
#        14.31342377, 66.26283019, 16.39700814, 38.55918893, 14.17290443,
#        96.78552525,  8.16193114, 51.79520389, 79.34731817, 36.09439135,
#        69.45662369, 37.08530875, 26.04075829, 19.41003774, 90.52424029,
#        83.43796756, 44.25419319,  4.28698995, 22.61640497, 66.29587954,
#        37.80471041, 46.59073483, 28.70598469, 54.93372676, 99.09382885,
#        18.51069529, 58.5200582 ,  6.48816149,  7.89198515, 75.55185597,
#        12.428369  , 54.34528308, 11.37340362, 89.60870577, 43.87212668,
#         7.06097615, 85.78786327, 68.32855058, 22.69759874, 54.08441743,
#        57.6810086 , 59.76296577, 18.40359837, 69.32014374, 14.77382419,
#        89.90176079, 85.21347564, 51.99064138, 53.5823145 , 31.85726035,
#        72.62904932, 35.14960029, 26.51132864, 14.32474565, 74.87707393,
# ...

# %% [markdown]
# > complete till here -> [Video Link](https://youtu.be/CMEWVn1uZpQ?t=10333)
